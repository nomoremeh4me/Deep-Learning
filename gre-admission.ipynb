# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/graduates-admission-prediction/admission_data.csv

# %%
df= pd.read_csv('/kaggle/input/graduates-admission-prediction/admission_data.csv')

# %%
df.shape
# Out:
# (500, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0

# %%
y.head()
# Out:
# 0    0.92
# 1    0.76
# 2    0.72
# 3    0.80
# 4    0.65
# Name: Chance of Admit , dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 238        310          104                  3  2.0   3.5  8.37         0
# 438        318          110                  1  2.5   3.5  8.54         1
# 475        300          101                  3  3.5   2.5  7.88         0
# 58         300           99                  1  3.0   2.0  6.80         1
# 380        322          104                  3  3.5   4.0  8.84         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 255        307          110                  4  4.0   4.5  8.37         0
# 72         321          111                  5  5.0   5.0  9.45         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 235        326          111                  5  4.5   4.0  9.23         1
# 37         300          105                  1  1.0   2.0  7.80         0
#
# [400 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.4       , 0.42857143, 0.5       , ..., 0.57142857, 0.50320513,
#         0.        ],
#        [0.56      , 0.64285714, 0.        , ..., 0.57142857, 0.55769231,
#         1.        ],
#        [0.2       , 0.32142857, 0.5       , ..., 0.28571429, 0.34615385,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.74038462,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.77884615,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.32051282,
#         0.        ]])

# %%
X_test_scaled
# Out:
# array([[ 0.46      ,  0.5       ,  0.25      ,  0.375     ,  0.14285714,
#          0.5224359 ,  0.        ],
#        [ 0.44      ,  0.53571429,  0.5       ,  0.5       ,  0.42857143,
#          0.53205128,  1.        ],
#        [ 0.98      ,  0.96428571,  1.        ,  0.875     ,  0.71428571,
#          0.92948718,  0.        ],
#        [ 0.52      ,  0.53571429,  0.25      ,  0.625     ,  0.57142857,
#          0.58974359,  1.        ],
#        [ 0.7       ,  0.64285714,  0.75      ,  0.875     ,  0.71428571,
#          0.69230769,  1.        ],
#        [ 0.42      ,  0.32142857,  0.25      ,  0.375     ,  0.57142857,
#          0.49358974,  1.        ],
#        [ 0.6       ,  0.42857143,  0.5       ,  0.5       ,  0.57142857,
#          0.62179487,  1.        ],
#        [ 0.52      ,  0.21428571,  0.        ,  0.125     ,  0.14285714,
#          0.20192308,  0.        ],
#        [ 0.72      ,  0.71428571,  0.5       ,  0.625     ,  0.42857143,
#          0.73717949,  1.        ],
#        [ 0.6       ,  0.32142857,  0.25      ,  0.375     ,  0.42857143,
#          0.58333333,  0.        ],
#        [ 0.48      ,  0.39285714,  0.25      ,  0.25      ,  0.42857143,
#          0.45192308,  0.        ],
#        [ 0.5       ,  0.46428571,  0.25      ,  0.5       ,  0.42857143,
#          0.49358974,  0.        ],
#        [ 0.88      ,  0.85714286,  0.75      ,  0.75      ,  0.57142857,
#          0.87820513,  1.        ],
#        [ 0.18      ,  0.28571429,  0.5       ,  0.25      ,  0.14285714,
#          0.39102564,  0.        ],
#        [ 0.42      ,  0.42857143,  0.5       ,  0.75      ,  0.57142857,
#          0.42628205,  1.        ],
#        [ 0.56      ,  0.32142857,  1.        ,  0.625     ,  1.        ,
#          0.63461538,  1.        ],
#        [ 0.86      ,  0.96428571,  1.        ,  1.        ,  0.85714286,
#          0.95512821,  1.        ],
#        [ 0.74      ,  0.75      ,  0.5       ,  0.625     ,  0.42857143,
#          0.59615385,  1.        ],
#        [ 0.14      ,  0.14285714,  0.25      ,  0.375     ,  0.        ,
#          0.34935897,  0.        ],
#        [ 0.54      ,  0.28571429,  0.25      ,  0.5       ,  0.28571429,
#          0.56730769,  0.        ],
#        [ 0.5       ,  0.42857143,  0.5       ,  0.75      ,  0.28571429,
#          0.41666667,  0.        ],
#        [ 0.64      ,  0.39285714,  0.75      ,  0.5       ,  0.28571429,
#          0.39102564,  1.        ],
#        [ 0.48      ,  0.5       ,  0.25      ,  0.75      ,  0.57142857,
#          0.46474359,  0.        ],
#        [ 0.78      ,  0.67857143,  0.75      ,  0.875     ,  0.71428571,
#          0.70833333,  1.        ],
#        [ 0.82      ,  0.89285714,  0.75      ,  0.875     ,  1.        ,
#          0.83974359,  1.        ],
#        [ 0.8       ,  0.82142857,  1.        ,  0.875     ,  0.42857143,
#          0.81410256,  1.        ],
#        [ 0.36      ,  0.35714286,  0.25      ,  0.25      ,  0.57142857,
#          0.37820513,  1.        ],
#        [ 0.5       ,  0.32142857,  0.5       ,  0.625     ,  0.85714286,
#          0.74679487,  0.        ],
#        [ 0.28      ,  0.46428571,  0.25      ,  0.5       ,  0.42857143,
#          0.44871795,  1.        ],
#        [ 0.44      ,  0.53571429,  0.75      ,  0.875     ,  0.71428571,
#          0.59294872,  1.        ],
#        [ 0.38      ,  0.5       ,  0.25      ,  0.375     ,  0.28571429,
#          0.38461538,  0.        ],
#        [ 0.58      ,  0.5       ,  0.5       ,  0.75      ,  0.42857143,
#          0.38461538,  1.        ],
#        [ 0.56      ,  0.53571429,  0.5       ,  0.5       ,  0.57142857,
#          0.47115385,  1.        ],
#        [ 0.18      ,  0.07142857,  0.        ,  0.        , -0.14285714,
#          0.17307692,  0.        ],
#        [ 0.58      ,  0.39285714,  0.75      ,  0.875     ,  0.57142857,
#          0.59615385,  0.        ],
#        [ 0.68      ,  0.28571429,  0.5       ,  0.75      ,  1.        ,
#          0.58974359,  1.        ],
#        [ 0.8       ,  0.78571429,  0.75      ,  0.875     ,  0.42857143,
#          0.75961538,  1.        ],
#        [ 0.9       ,  0.89285714,  1.        ,  1.        ,  1.        ,
#          0.96794872,  1.        ],
#        [ 0.36      ,  0.42857143,  0.25      ,  0.375     ,  0.42857143,
#          0.40705128,  0.        ],
#        [ 0.6       ,  0.57142857,  0.5       ,  0.625     ,  0.71428571,
#          0.52564103,  1.        ],
#        [ 0.68      ,  0.53571429,  1.        ,  0.625     ,  0.71428571,
#          0.59615385,  1.        ],
#        [ 1.        ,  0.71428571,  0.75      ,  1.        ,  0.85714286,
#          0.91666667,  1.        ],
#        [ 0.56      ,  0.60714286,  0.5       ,  0.5       ,  0.42857143,
#          0.54487179,  0.        ],
#        [ 0.3       ,  0.35714286,  0.25      ,  0.25      ,  0.28571429,
#          0.44230769,  0.        ],
#        [ 0.5       ,  0.42857143,  0.5       ,  0.5       ,  0.28571429,
#          0.49038462,  0.        ],
#        [ 0.72      ,  0.78571429,  0.5       ,  0.5       ,  0.42857143,
#          0.74038462,  1.        ],
#        [ 0.4       ,  0.25      ,  0.25      ,  0.125     ,  0.14285714,
#          0.16025641,  0.        ],
#        [ 0.96      ,  0.89285714,  0.75      ,  0.625     ,  0.85714286,
#          0.8525641 ,  1.        ],
#        [ 0.28      ,  0.53571429,  0.5       ,  0.625     ,  0.42857143,
#          0.33974359,  0.        ],
#        [ 0.84      ,  0.57142857,  1.        ,  0.875     ,  0.71428571,
#          0.71153846,  1.        ],
#        [ 0.66      ,  0.67857143,  1.        ,  0.75      ,  1.        ,
#          0.98076923,  1.        ],
#        [ 0.6       ,  0.42857143,  0.5       ,  0.5       ,  0.28571429,
#          0.56730769,  1.        ],
#        [ 0.48      ,  0.60714286,  0.75      ,  0.625     ,  0.71428571,
#          0.63141026,  1.        ],
#        [ 0.74      ,  0.57142857,  1.        ,  1.        ,  0.57142857,
#          0.74679487,  1.        ],
#        [ 0.        ,  0.42857143,  0.75      ,  0.25      ,  0.28571429,
#          0.21153846,  0.        ],
#        [ 0.9       ,  0.92857143,  1.        ,  0.875     ,  0.57142857,
#          0.84615385,  1.        ],
#        [ 0.74      ,  0.5       ,  0.75      ,  0.75      ,  0.85714286,
#          0.625     ,  1.        ],
#        [ 0.64      ,  0.64285714,  1.        ,  0.875     ,  0.71428571,
#          0.69551282,  0.        ],
#        [ 0.36      ,  0.60714286,  0.25      ,  0.5       ,  0.71428571,
#          0.52884615,  0.        ],
#        [ 0.68      ,  0.75      ,  1.        ,  0.75      ,  1.        ,
#          0.78525641,  1.        ],
#        [ 0.82      ,  0.85714286,  1.        ,  0.75      ,  0.71428571,
#          0.78846154,  1.        ],
#        [ 0.14      ,  0.25      ,  0.75      ,  0.5       ,  0.57142857,
#          0.32371795,  0.        ],
#        [ 0.28      ,  0.42857143,  0.5       ,  0.375     ,  0.14285714,
#          0.42307692,  0.        ],
#        [ 0.38      ,  0.46428571,  0.75      ,  0.625     ,  0.14285714,
#          0.44230769,  0.        ],
#        [ 0.62      ,  0.35714286,  0.5       ,  0.625     ,  0.71428571,
#          0.70833333,  1.        ],
#        [ 0.52      ,  0.39285714,  0.5       ,  0.625     ,  0.14285714,
#          0.28205128,  0.        ],
#        [ 0.62      ,  0.60714286,  0.5       ,  0.5       ,  0.71428571,
#          0.44871795,  1.        ],
#        [ 0.64      ,  0.71428571,  0.75      ,  0.625     ,  0.28571429,
#          0.71153846,  1.        ],
#        [ 0.74      ,  0.67857143,  0.75      ,  0.75      ,  0.85714286,
#          0.70512821,  1.        ],
#        [ 0.64      ,  0.78571429,  1.        ,  0.875     ,  0.71428571,
#          0.68589744,  1.        ],
#        [ 0.16      ,  0.21428571,  0.25      ,  0.75      ,  0.42857143,
#          0.39423077,  0.        ],
#        [ 0.52      ,  0.64285714,  0.5       ,  0.625     ,  0.71428571,
#          0.56410256,  0.        ],
#        [ 0.3       ,  0.57142857,  1.        ,  0.5       ,  0.42857143,
#          0.53846154,  0.        ]])

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
# Out:
# 2025-06-09 05:23:10.875313: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749446591.284996      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749446591.387078      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
model = Sequential()

model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(1,activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 7)                   │              56 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               8 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 64 (256.00 B)
#  Trainable params: 64 (256.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error',optimizer='Adam')

# %%
history = model.fit(X_train_scaled,y_train,epochs=25,validation_split=0.2)
# Out:
# Epoch 1/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.8385 - val_loss: 0.8230
# Epoch 2/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7338 - val_loss: 0.6944
# Epoch 3/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6087 - val_loss: 0.5831
# Epoch 4/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5111 - val_loss: 0.4893
# Epoch 5/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4313 - val_loss: 0.4095
# Epoch 6/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3519 - val_loss: 0.3345
# Epoch 7/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2816 - val_loss: 0.2620
# Epoch 8/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2219 - val_loss: 0.1937
# Epoch 9/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1589 - val_loss: 0.1324
# Epoch 10/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1074 - val_loss: 0.0813
# Epoch 11/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0604 - val_loss: 0.0448
# Epoch 12/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0332 - val_loss: 0.0223
# Epoch 13/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0201 - val_loss: 0.0132
# Epoch 14/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0151 - val_loss: 0.0119
# Epoch 15/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146 - val_loss: 0.0112
# Epoch 16/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0136 - val_loss: 0.0106
# Epoch 17/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0137 - val_loss: 0.0102
# Epoch 18/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0115 - val_loss: 0.0098
# Epoch 19/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095 - val_loss: 0.0094
# Epoch 20/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0104 - val_loss: 0.0091
# Epoch 21/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0106 - val_loss: 0.0088
# Epoch 22/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0099 - val_loss: 0.0086
# Epoch 23/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0118 - val_loss: 0.0084
# Epoch 24/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0106 - val_loss: 0.0082
# Epoch 25/25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0090 - val_loss: 0.0081

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6958448673495146

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
