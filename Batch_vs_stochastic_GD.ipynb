# %%
import numpy as np
import pandas as pd
import time

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df = df[['Age','EstimatedSalary','Purchased']]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (400, 2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
start = time.time()
history = model.fit(X_scaled,y,epochs=25,batch_size=1,validation_split=0.2)
print(time.time()-start)
# Out:
# Epoch 1/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9036 - loss: 0.2781 - val_accuracy: 0.9750 - val_loss: 0.1946
# Epoch 2/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8688 - loss: 0.2840 - val_accuracy: 0.9750 - val_loss: 0.1916
# Epoch 3/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8787 - loss: 0.2713 - val_accuracy: 0.9875 - val_loss: 0.1952
# Epoch 4/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8966 - loss: 0.2516 - val_accuracy: 0.9875 - val_loss: 0.1905
# Epoch 5/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9206 - loss: 0.2144 - val_accuracy: 0.9875 - val_loss: 0.1897
# Epoch 6/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8665 - loss: 0.2997 - val_accuracy: 0.9875 - val_loss: 0.1807
# Epoch 7/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8987 - loss: 0.2631 - val_accuracy: 0.9875 - val_loss: 0.1760
# Epoch 8/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9097 - loss: 0.2647 - val_accuracy: 0.9875 - val_loss: 0.1710
# Epoch 9/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8866 - loss: 0.2640 - val_accuracy: 0.9750 - val_loss: 0.1782
# Epoch 10/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8928 - loss: 0.2384 - val_accuracy: 0.9875 - val_loss: 0.1754
# Epoch 11/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8624 - loss: 0.3277 - val_accuracy: 0.9750 - val_loss: 0.1719
# Epoch 12/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9047 - loss: 0.2203 - val_accuracy: 0.9875 - val_loss: 0.1665
# Epoch 13/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9035 - loss: 0.2521 - val_accuracy: 0.9875 - val_loss: 0.1687
# Epoch 14/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9007 - loss: 0.2615 - val_accuracy: 0.9875 - val_loss: 0.1648
# Epoch 15/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8707 - loss: 0.3716 - val_accuracy: 0.9875 - val_loss: 0.1617
# Epoch 16/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8896 - loss: 0.2859 - val_accuracy: 0.9875 - val_loss: 0.1556
# Epoch 17/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9119 - loss: 0.3009 - val_accuracy: 0.9750 - val_loss: 0.1607
# Epoch 18/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9036 - loss: 0.2510 - val_accuracy: 0.9750 - val_loss: 0.1627
# Epoch 19/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8944 - loss: 0.2784 - val_accuracy: 0.9750 - val_loss: 0.1594
# Epoch 20/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.2242 - val_accuracy: 0.9750 - val_loss: 0.1572
# Epoch 21/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8812 - loss: 0.3446 - val_accuracy: 0.9875 - val_loss: 0.1530
# Epoch 22/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9157 - loss: 0.1997 - val_accuracy: 0.9750 - val_loss: 0.1553
# Epoch 23/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9047 - loss: 0.2687 - val_accuracy: 0.9750 - val_loss: 0.1502
# Epoch 24/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9310 - loss: 0.2317 - val_accuracy: 0.9875 - val_loss: 0.1494
# Epoch 25/25
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8992 - loss: 0.2599 - val_accuracy: 0.9750 - val_loss: 0.1644
# 38.202592611312866

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=25,batch_size=250,validation_split=0.2)
#print(time.time() - start)
# Out:
# Epoch 1/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 458ms/step - accuracy: 0.5768 - loss: 0.6872 - val_accuracy: 0.7250 - val_loss: 0.6714
# Epoch 2/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6858 - loss: 0.6817 - val_accuracy: 0.8250 - val_loss: 0.6666
# Epoch 3/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7697 - loss: 0.6777 - val_accuracy: 0.7750 - val_loss: 0.6662
# Epoch 4/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7810 - loss: 0.6760 - val_accuracy: 0.8500 - val_loss: 0.6637
# Epoch 5/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8419 - loss: 0.6741 - val_accuracy: 0.8875 - val_loss: 0.6613
# Epoch 6/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8603 - loss: 0.6714 - val_accuracy: 0.9125 - val_loss: 0.6585
# Epoch 7/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8717 - loss: 0.6693 - val_accuracy: 0.8875 - val_loss: 0.6559
# Epoch 8/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8609 - loss: 0.6670 - val_accuracy: 0.9125 - val_loss: 0.6541
# Epoch 9/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8692 - loss: 0.6655 - val_accuracy: 0.9250 - val_loss: 0.6512
# Epoch 10/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8672 - loss: 0.6639 - val_accuracy: 0.9250 - val_loss: 0.6487
# Epoch 11/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8645 - loss: 0.6619 - val_accuracy: 0.9000 - val_loss: 0.6450
# Epoch 12/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8657 - loss: 0.6606 - val_accuracy: 0.9000 - val_loss: 0.6425
# Epoch 13/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8670 - loss: 0.6575 - val_accuracy: 0.9000 - val_loss: 0.6409
# Epoch 14/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8630 - loss: 0.6566 - val_accuracy: 0.9250 - val_loss: 0.6393
# Epoch 15/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8685 - loss: 0.6544 - val_accuracy: 0.9250 - val_loss: 0.6370
# Epoch 16/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8679 - loss: 0.6534 - val_accuracy: 0.9375 - val_loss: 0.6345
# Epoch 17/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8692 - loss: 0.6511 - val_accuracy: 0.9375 - val_loss: 0.6308
# Epoch 18/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8753 - loss: 0.6491 - val_accuracy: 0.9375 - val_loss: 0.6276
# Epoch 19/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8719 - loss: 0.6460 - val_accuracy: 0.9375 - val_loss: 0.6276
# Epoch 20/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8753 - loss: 0.6430 - val_accuracy: 0.9375 - val_loss: 0.6255
# Epoch 21/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8753 - loss: 0.6404 - val_accuracy: 0.9375 - val_loss: 0.6225
# Epoch 22/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8774 - loss: 0.6370 - val_accuracy: 0.9375 - val_loss: 0.6220
# Epoch 23/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8761 - loss: 0.6366 - val_accuracy: 0.9375 - val_loss: 0.6205
# Epoch 24/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8814 - loss: 0.6323 - val_accuracy: 0.9375 - val_loss: 0.6185
# Epoch 25/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8788 - loss: 0.6306 - val_accuracy: 0.9375 - val_loss: 0.6155

# %%
plt.plot(history.history['loss'])
